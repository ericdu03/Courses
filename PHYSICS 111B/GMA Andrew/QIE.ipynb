# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
data = pd.read_table("QIE-data.txt")
display(data)

new_data = data[['A', 'B', 'AB', 'HWP A', 'HWP B']]
display(new_data)

print(new_data.to_latex(index=False,column_format='|c|c|c|c|c|'))
# Out:
#           A        B   A'   B'  A'B      AB  AB'  A'B'  HWP A  HWP B    E  \
# 0   72342.1  49577.2  0.0  0.0  0.0   803.9  0.0   0.0  -45.0  -22.5  1.0
# 1   72308.2  49361.3  0.0  0.0  0.0   279.6  0.0   0.0  -45.0   22.5  1.0
# 2   72591.5  50345.6  0.0  0.0  0.0   371.4  0.0   0.0  -45.0   67.5  1.0
# 3   72305.0  49995.7  0.0  0.0  0.0   926.3  0.0   0.0  -45.0  112.5  1.0
# 4   70554.0  49509.4  0.0  0.0  0.0   944.6  0.0   0.0    0.0  -22.5  1.0
# 5   70615.3  49260.2  0.0  0.0  0.0   863.2  0.0   0.0    0.0   22.5  1.0
# 6   70596.1  49982.3  0.0  0.0  0.0   202.0  0.0   0.0    0.0   67.5  1.0
# 7   70411.7  50038.5  0.0  0.0  0.0   304.5  0.0   0.0    0.0  112.5  1.0
# 8   71712.9  49501.5  0.0  0.0  0.0   367.3  0.0   0.0   45.0  -22.5  1.0
# 9   71600.2  49387.4  0.0  0.0  0.0   902.3  0.0   0.0   45.0   22.5  1.0
# 10  71701.8  50091.0  0.0  0.0  0.0   817.2  0.0   0.0   45.0   67.5  1.0
# 11  71877.2  50143.6  0.0  0.0  0.0   254.6  0.0   0.0   45.0  112.5  1.0
# ...
