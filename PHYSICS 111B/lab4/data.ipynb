# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# %%
count_A = np.array([65042, 42360, 7738, 17432, 56312, 60688, 23176, 5720, 38100, 66370])

angle_A = np.array([0.5, 20, 40, 60, 80, 100, 120, 140, 160, 180])

count_B = np.array([64426, 63434, 31400, 4806, 25706, 59530, 52033, 14239, 9355, 44214])

angle_B = np.array([-65, -60, -40, -20, 0, 20, 40, 60, 80, 100])

# %%
plt.plot(angle_A, count_A, c = 'orange')
plt.plot(angle_B, count_B, c = 'blue')
plt.legend(['A', 'B'])
plt.show()

print(f"Contrast A: {(3654 - 23)/(3654 + 23)}")
print(f"Contrast B: {(3781 - 41)/(3781 + 41)}")
# Out:
# Contrast A: 0.9874898014685886
# Contrast B: 0.97854526425955
